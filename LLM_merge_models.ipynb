# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinJayne2023/Merged-LLMs/blob/main/LLM_merge_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install bitsandbytes accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !git clone https://github.com/arcee-ai/mergekit.git
# %cd mergekit
# !pip install -e .
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 3154, done.
# remote: Counting objects: 100% (1273/1273), done.
# remote: Compressing objects: 100% (396/396), done.
# remote: Total 3154 (delta 1097), reused 878 (delta 877), pack-reused 1881 (from 4)
# Receiving objects: 100% (3154/3154), 1.09 MiB | 6.73 MiB/s, done.
# Resolving deltas: 100% (2153/2153), done.
# /content/mergekit
# Obtaining file:///content/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 27.7 MB/s eta 0:00:00
# ...

# %%
# YAML FILE:

# models:
#   - model: nvidia/Llama-3.1-Nemotron-Nano-4B-v1.1
#     parameters:
#       weight: 0.3
#   - model: nvidia/Llama-3.1-Nemotron-70B-Instruct-HF
#     parameters:
#       weight: 0.4
#   - model: deepseek-ai/DeepSeek-R1-Distill-Llama-8B
#     parameters:
#       weight: 0.3
# merge_method: generalized task arithmetic
# tokenizer_source: union
# dtype: float16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import yaml

from mergekit.config import MergeConfiguration
from mergekit.merge import MergeOptions, run_merge

# %%
OUTPUT_PATH = './models/llm-merged'
LORA_MERGE_CACHE = '/tmp'
CONFIG_YML = '/content/mergekit/config.yml'
COPY_TOKENIZER = True
LAZY_UNPICKLE = True
LOW_CPU_MEMORY = True


with open(CONFIG_YML, 'r', encoding='utf-8') as fp:
    merge_config = MergeConfiguration.model_validate(yaml.safe_load(fp))

run_merge(
    merge_config,
    out_path = OUTPUT_PATH,
    options=MergeOptions(
        lora_merge_cache = LORA_MERGE_CACHE,
        copy_tokenizer = COPY_TOKENIZER,
        lazy_unpickle = LAZY_UNPICKLE,
        low_cpu_memory = LOW_CPU_MEMORY,
        cuda=torch.cuda.is_available()
    )
)
print("Done!")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/930 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/910 [00:00<?, ?B/s]
# ...
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.07k [00:00<?, ?B/s]
# ...

# %%
from huggingface_hub import HfApi

api = HfApi(token=os.getenv("HF_TOKEN"))
api.upload_folder(
    folder_path="/path/to/local/model",
    repo_id="KevinJayne2023/jayne-llama-merged",
    repo_type="model",
)
